# %% [markdown]
# ## 1. Imports & Core Dependencies
# This cell loads all Python libraries required for data ingestion, feature processing, and modelling.
# It also ensures consistent datetime and filesystem handling across the notebook.

# %%
#Imports 
import os, json, datetime
import numpy as np
import pandas as pd
import fastf1 as ff1

from pathlib import Path
import datetime

# %% [markdown]
# ## 2. Output Directory Sanity Check
# This cell verifies that the notebook has write access to the processed data directory.
# A temporary file is written to confirm relative paths resolve correctly.

# %%
#Path Checker Cell

OUT_DIR   = "../../data_processed"

OUT_DIR = Path(OUT_DIR)   # <-- this is the missing line
testp_file = OUT_DIR / "_parquets_path_test.txt"
with open(testp_file, "w") as f:
    f.write(f"Parquets test written at {datetime.datetime.now().isoformat()}\n")
    f.write(f"Works from the ml notebook fool\n")


print("Test file written to:", testp_file)
# Out:
# Test file written to: ..\..\data_processed\_parquets_path_test.txt

# %% [markdown]
# ## 3. Load Pre-Qualifying Dataset & Inspect Coverage
# This cell loads the consolidated parquet dataset and inspects:
# - dataset dimensions
# - number of samples per season (year)
#
# This ensures the expected seasons are present before any splitting.

# %%
#Checks DF shape
from pathlib import Path
import pandas as pd


DATASET_PATH = OUT_DIR / "preq_dataset.parquet"

df = pd.read_parquet(DATASET_PATH)
print(df.shape)
print(df["year"].value_counts().sort_index())
# Out:
# (3456, 16)
# year
# 2018    420
# 2019    420
# 2020    339
# 2021    440
# 2022    440
# 2023    438
# 2024    479
# 2025    480
# Name: count, dtype: int64

# %% [markdown]
# ## 4. Temporal Train–Test Split (2022–23 Train, 2024 Test)
# The dataset is split chronologically:
# - Training data: 2022–2023
# - Hold-out test data: 2024
#
# This mimics real-world deployment and prevents look-ahead bias.

# %%
train_df = df[df["year"].isin([2022, 2023])].copy()
test_df  = df[df["year"] == 2024].copy()
print(train_df["year"].value_counts().sort_index())
print(test_df["year"].value_counts().sort_index())

print(len(train_df), len(test_df))
# Out:
# year
# 2022    440
# 2023    438
# Name: count, dtype: int64
# year
# 2024    479
# Name: count, dtype: int64
# 878 479

# %% [markdown]
# ## 5. Feature Matrix and Target Construction
# This cell:
# - defines the prediction target (`quali_position`)
# - removes identifiers and metadata from features
# - constructs X/y for both training and test splits
#
# Only pre-qualifying information is retained in X to avoid leakage.

# %%
TARGET = "quali_position"
DROP_COLS = ["year", "round", "event_name", "country", "location", "driver"]

X_train = train_df.drop(columns=DROP_COLS + [TARGET])
y_train = train_df[TARGET]

X_test = test_df.drop(columns=DROP_COLS + [TARGET])
y_test = test_df[TARGET]

X = df.drop(columns=DROP_COLS + [TARGET], errors="ignore")
y = df[TARGET].astype(float)

# %% [markdown]
# ## 6. Baseline Model with Leave-One-Year-Out (LOYO) Validation
# A baseline XGBoost regressor is evaluated using LOYO cross-validation
# within the training period (2022–2023).
#
# Each fold holds out one full season to assess temporal generalisation.

# %%
from sklearn.model_selection import GroupKFold
from sklearn.metrics import mean_absolute_error
from xgboost import XGBRegressor

groups = train_df["year"]

gkf = GroupKFold(n_splits=groups.nunique())

maes = []

for train_idx, val_idx in gkf.split(X_train, y_train, groups):
    Xtr, Xval = X_train.iloc[train_idx], X_train.iloc[val_idx]
    ytr, yval = y_train.iloc[train_idx], y_train.iloc[val_idx]

    model = XGBRegressor(
        n_estimators=200,
        max_depth=3,
        learning_rate=0.05,
        subsample=0.8,
        colsample_bytree=0.8,
        random_state=42,
        objective="reg:squarederror"
    )

    model.fit(Xtr, ytr)
    preds = model.predict(Xval)
    maes.append(mean_absolute_error(yval, preds))

print("Baseline LOYO MAE:", sum(maes)/len(maes))
# Out:
# Baseline LOYO MAE: 5.2029931238747675

# %% [markdown]
# ## 7. Hyperparameter Optimisation via Optuna (LOYO Objective)
# Optuna is used to tune XGBoost hyperparameters.
#
# The optimisation objective is the mean LOYO MAE across training seasons,
# ensuring hyperparameters generalise temporally rather than overfitting.

# %%
import optuna
import numpy as np
from sklearn.metrics import mean_absolute_error
from xgboost import XGBRegressor

# assumes these already exist from your baseline cell:
# X_train, y_train, train_df
# groups = train_df["year"]
# gkf = GroupKFold(n_splits=groups.nunique())

def objective(trial):
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 200, 800),
        "max_depth": trial.suggest_int("max_depth", 2, 6),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.2, log=True),
        "subsample": trial.suggest_float("subsample", 0.6, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.6, 1.0),
        "objective": "reg:squarederror",
        "random_state": 42,
        "n_jobs": -1,
    }

    maes = []

    for tr_idx, val_idx in gkf.split(X_train, y_train, groups):
        model = XGBRegressor(**params)
        model.fit(X_train.iloc[tr_idx], y_train.iloc[tr_idx])
        preds = model.predict(X_train.iloc[val_idx])
        maes.append(mean_absolute_error(y_train.iloc[val_idx], preds))

    return float(np.mean(maes))

study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=40)

print("Best CV (LOYO) MAE:", study.best_value)
print("Best params:", study.best_params)
# Out:
# [I 2026-03-02 09:34:36,241] A new study created in memory with name: no-name-add46f37-c1dd-4584-858f-ce4e6c8a7b8c
# [I 2026-03-02 09:34:36,754] Trial 0 finished with value: 5.456104150724985 and parameters: {'n_estimators': 378, 'max_depth': 6, 'learning_rate': 0.036832750394302324, 'subsample': 0.8758147103603346, 'colsample_bytree': 0.8959057351342763}. Best is trial 0 with value: 5.456104150724985.
# [I 2026-03-02 09:34:37,638] Trial 1 finished with value: 5.420825776626035 and parameters: {'n_estimators': 701, 'max_depth': 6, 'learning_rate': 0.024256885589252184, 'subsample': 0.6228047665656391, 'colsample_bytree': 0.8144922364093883}. Best is trial 1 with value: 5.420825776626035.
# [I 2026-03-02 09:34:37,996] Trial 2 finished with value: 5.577487959281297 and parameters: {'n_estimators': 348, 'max_depth': 5, 'learning_rate': 0.09528000167025714, 'subsample': 0.7404524671435272, 'colsample_bytree': 0.622491778776144}. Best is trial 1 with value: 5.420825776626035.
# [I 2026-03-02 09:34:38,377] Trial 3 finished with value: 5.383471640284165 and parameters: {'n_estimators': 300, 'max_depth': 6, 'learning_rate': 0.04761817359652322, 'subsample': 0.8076230450301731, 'colsample_bytree': 0.9436928940501582}. Best is trial 3 with value: 5.383471640284165.
# [I 2026-03-02 09:34:38,536] Trial 4 finished with value: 5.226613370456256 and parameters: {'n_estimators': 317, 'max_depth': 2, 'learning_rate': 0.04421249034776461, 'subsample': 0.6235696556414294, 'colsample_bytree': 0.7566512707420455}. Best is trial 4 with value: 5.226613370456256.
# [I 2026-03-02 09:34:39,017] Trial 5 finished with value: 5.565543849589346 and parameters: {'n_estimators': 356, 'max_depth': 6, 'learning_rate': 0.0710281506230204, 'subsample': 0.9384075990322347, 'colsample_bytree': 0.6349791175324632}. Best is trial 4 with value: 5.226613370456256.
# [I 2026-03-02 09:34:39,371] Trial 6 finished with value: 5.400118169526234 and parameters: {'n_estimators': 360, 'max_depth': 5, 'learning_rate': 0.04282619378166053, 'subsample': 0.6336199889570122, 'colsample_bytree': 0.7177379936821326}. Best is trial 4 with value: 5.226613370456256.
# [I 2026-03-02 09:34:40,294] Trial 7 finished with value: 5.385344586565615 and parameters: {'n_estimators': 742, 'max_depth': 6, 'learning_rate': 0.02878457064786602, 'subsample': 0.6120321313922241, 'colsample_bytree': 0.8531731859453819}. Best is trial 4 with value: 5.226613370456256.
# [I 2026-03-02 09:34:40,563] Trial 8 finished with value: 5.450574426494164 and parameters: {'n_estimators': 269, 'max_depth': 5, 'learning_rate': 0.07036123187503195, 'subsample': 0.607149179601643, 'colsample_bytree': 0.7053650771958343}. Best is trial 4 with value: 5.226613370456256.
# [I 2026-03-02 09:34:40,884] Trial 9 finished with value: 5.184431366311311 and parameters: {'n_estimators': 531, 'max_depth': 3, 'learning_rate': 0.015119366169403271, 'subsample': 0.8738822872435448, 'colsample_bytree': 0.9523533636100481}. Best is trial 9 with value: 5.184431366311311.
# [I 2026-03-02 09:34:41,148] Trial 10 finished with value: 5.111195253115959 and parameters: {'n_estimators': 563, 'max_depth': 2, 'learning_rate': 0.01139899809198172, 'subsample': 0.9994015866339331, 'colsample_bytree': 0.9902906239313812}. Best is trial 10 with value: 5.111195253115959.
# [I 2026-03-02 09:34:41,421] Trial 11 finished with value: 5.114546141289438 and parameters: {'n_estimators': 579, 'max_depth': 2, 'learning_rate': 0.011149248609974585, 'subsample': 0.9956787203161901, 'colsample_bytree': 0.9854741265285522}. Best is trial 10 with value: 5.111195253115959.
# [I 2026-03-02 09:34:41,688] Trial 12 finished with value: 5.100797143235846 and parameters: {'n_estimators': 583, 'max_depth': 2, 'learning_rate': 0.010306379206416104, 'subsample': 0.9772366671178772, 'colsample_bytree': 0.9889009285299594}. Best is trial 12 with value: 5.100797143235846.
# [I 2026-03-02 09:34:42,080] Trial 13 finished with value: 5.961192945531044 and parameters: {'n_estimators': 646, 'max_depth': 3, 'learning_rate': 0.1964023950358137, 'subsample': 0.993135598629619, 'colsample_bytree': 0.9999426202754407}. Best is trial 12 with value: 5.100797143235846.
# [I 2026-03-02 09:34:42,366] Trial 14 finished with value: 5.164909960138397 and parameters: {'n_estimators': 455, 'max_depth': 3, 'learning_rate': 0.0168236496834937, 'subsample': 0.9261691419937608, 'colsample_bytree': 0.8981163752313749}. Best is trial 12 with value: 5.100797143235846.
# [I 2026-03-02 09:34:42,667] Trial 15 finished with value: 5.108916982759723 and parameters: {'n_estimators': 610, 'max_depth': 2, 'learning_rate': 0.01081351515218731, 'subsample': 0.939372681653238, 'colsample_bytree': 0.910924487978445}. Best is trial 12 with value: 5.100797143235846.
# [I 2026-03-02 09:34:43,183] Trial 16 finished with value: 5.367754434286039 and parameters: {'n_estimators': 656, 'max_depth': 4, 'learning_rate': 0.020161560783220404, 'subsample': 0.9257777788159698, 'colsample_bytree': 0.8847194197865625}. Best is trial 12 with value: 5.100797143235846.
# [I 2026-03-02 09:34:43,631] Trial 17 finished with value: 5.1689269888148655 and parameters: {'n_estimators': 778, 'max_depth': 3, 'learning_rate': 0.010361401605610623, 'subsample': 0.8138534749352699, 'colsample_bytree': 0.9326527202511758}. Best is trial 12 with value: 5.100797143235846.
# [I 2026-03-02 09:34:43,855] Trial 18 finished with value: 5.092598462386862 and parameters: {'n_estimators': 459, 'max_depth': 2, 'learning_rate': 0.015319147992129722, 'subsample': 0.865431574548913, 'colsample_bytree': 0.8456079241900488}. Best is trial 18 with value: 5.092598462386862.
# [I 2026-03-02 09:34:44,221] Trial 19 finished with value: 5.199588867825263 and parameters: {'n_estimators': 452, 'max_depth': 4, 'learning_rate': 0.015374470519437576, 'subsample': 0.7596926711611053, 'colsample_bytree': 0.8272797008613407}. Best is trial 18 with value: 5.092598462386862.
# [I 2026-03-02 09:34:44,424] Trial 20 finished with value: 5.1595549531005735 and parameters: {'n_estimators': 221, 'max_depth': 4, 'learning_rate': 0.02657735853881625, 'subsample': 0.8731377360570756, 'colsample_bytree': 0.8557759430767029}. Best is trial 18 with value: 5.092598462386862.
# [I 2026-03-02 09:34:44,708] Trial 21 finished with value: 5.129300746770754 and parameters: {'n_estimators': 613, 'max_depth': 2, 'learning_rate': 0.013621764134267541, 'subsample': 0.9535231893083779, 'colsample_bytree': 0.7797623093695314}. Best is trial 18 with value: 5.092598462386862.
# [I 2026-03-02 09:34:44,941] Trial 22 finished with value: 5.160488990324074 and parameters: {'n_estimators': 477, 'max_depth': 2, 'learning_rate': 0.02070079069452224, 'subsample': 0.8552636264740431, 'colsample_bytree': 0.922831678865354}. Best is trial 18 with value: 5.092598462386862.
# [I 2026-03-02 09:34:45,185] Trial 23 finished with value: 5.081907416778067 and parameters: {'n_estimators': 509, 'max_depth': 2, 'learning_rate': 0.010121039752505804, 'subsample': 0.959084739264267, 'colsample_bytree': 0.9622590675957559}. Best is trial 23 with value: 5.081907416778067.
# [I 2026-03-02 09:34:45,444] Trial 24 finished with value: 5.092066378799302 and parameters: {'n_estimators': 416, 'max_depth': 3, 'learning_rate': 0.01380339276882267, 'subsample': 0.8981724285289975, 'colsample_bytree': 0.8647422695963702}. Best is trial 23 with value: 5.081907416778067.
# [I 2026-03-02 09:34:45,709] Trial 25 finished with value: 5.160765214743778 and parameters: {'n_estimators': 423, 'max_depth': 3, 'learning_rate': 0.018097453572736552, 'subsample': 0.8384075128428979, 'colsample_bytree': 0.869965770866047}. Best is trial 23 with value: 5.081907416778067.
# [I 2026-03-02 09:34:46,033] Trial 26 finished with value: 5.112584950667587 and parameters: {'n_estimators': 512, 'max_depth': 3, 'learning_rate': 0.012979426393489646, 'subsample': 0.8915318543684244, 'colsample_bytree': 0.8323869503004132}. Best is trial 23 with value: 5.081907416778067.
# [I 2026-03-02 09:34:46,314] Trial 27 finished with value: 5.2922362345452125 and parameters: {'n_estimators': 421, 'max_depth': 3, 'learning_rate': 0.030954626906790825, 'subsample': 0.7691528151064393, 'colsample_bytree': 0.7851767682750762}. Best is trial 23 with value: 5.081907416778067.
# [I 2026-03-02 09:34:46,510] Trial 28 finished with value: 5.113196239683232 and parameters: {'n_estimators': 411, 'max_depth': 2, 'learning_rate': 0.020139655350200316, 'subsample': 0.682593832935404, 'colsample_bytree': 0.7483422650366255}. Best is trial 23 with value: 5.081907416778067.
# [I 2026-03-02 09:34:46,833] Trial 29 finished with value: 5.150944162647276 and parameters: {'n_estimators': 527, 'max_depth': 3, 'learning_rate': 0.01356502627249862, 'subsample': 0.9016333571357631, 'colsample_bytree': 0.953744685893626}. Best is trial 23 with value: 5.081907416778067.
# [I 2026-03-02 09:34:47,069] Trial 30 finished with value: 5.1734740660293514 and parameters: {'n_estimators': 489, 'max_depth': 2, 'learning_rate': 0.022370084474379177, 'subsample': 0.9046803387853797, 'colsample_bytree': 0.8843040348167516}. Best is trial 23 with value: 5.081907416778067.
# [I 2026-03-02 09:34:47,325] Trial 31 finished with value: 5.1250817162112705 and parameters: {'n_estimators': 559, 'max_depth': 2, 'learning_rate': 0.01265234847813445, 'subsample': 0.9711497026790393, 'colsample_bytree': 0.9690362181713947}. Best is trial 23 with value: 5.081907416778067.
# [I 2026-03-02 09:34:47,511] Trial 32 finished with value: 5.061694293348261 and parameters: {'n_estimators': 389, 'max_depth': 2, 'learning_rate': 0.01009816635413452, 'subsample': 0.967374629033853, 'colsample_bytree': 0.9118118651665575}. Best is trial 32 with value: 5.061694293348261.
# [I 2026-03-02 09:34:47,699] Trial 33 finished with value: 5.09397004466425 and parameters: {'n_estimators': 379, 'max_depth': 2, 'learning_rate': 0.016399782318789084, 'subsample': 0.8346433182400207, 'colsample_bytree': 0.8129441219566794}. Best is trial 32 with value: 5.061694293348261.
# [I 2026-03-02 09:34:48,010] Trial 34 finished with value: 5.1124946968987945 and parameters: {'n_estimators': 401, 'max_depth': 3, 'learning_rate': 0.01332078756423807, 'subsample': 0.9614471271388125, 'colsample_bytree': 0.8515284374301691}. Best is trial 32 with value: 5.061694293348261.
# [I 2026-03-02 09:34:48,234] Trial 35 finished with value: 5.878024177730467 and parameters: {'n_estimators': 308, 'max_depth': 2, 'learning_rate': 0.1915399939677372, 'subsample': 0.9145569692495309, 'colsample_bytree': 0.9124576713539884}. Best is trial 32 with value: 5.061694293348261.
# [I 2026-03-02 09:34:48,546] Trial 36 finished with value: 5.255310657982907 and parameters: {'n_estimators': 449, 'max_depth': 2, 'learning_rate': 0.035480163129809096, 'subsample': 0.8884233300719857, 'colsample_bytree': 0.8887767886119881}. Best is trial 32 with value: 5.061694293348261.
# [I 2026-03-02 09:34:48,944] Trial 37 finished with value: 5.111155294439218 and parameters: {'n_estimators': 334, 'max_depth': 4, 'learning_rate': 0.010082474064587156, 'subsample': 0.94999097407711, 'colsample_bytree': 0.9352420437615327}. Best is trial 32 with value: 5.061694293348261.
# [I 2026-03-02 09:34:49,338] Trial 38 finished with value: 5.7038198779571 and parameters: {'n_estimators': 386, 'max_depth': 3, 'learning_rate': 0.12395303935330515, 'subsample': 0.8665309543062236, 'colsample_bytree': 0.8341169390890282}. Best is trial 32 with value: 5.061694293348261.
# [I 2026-03-02 09:34:49,565] Trial 39 finished with value: 5.229523388636265 and parameters: {'n_estimators': 259, 'max_depth': 2, 'learning_rate': 0.05203395086116738, 'subsample': 0.8431449314016775, 'colsample_bytree': 0.7994504675405373}. Best is trial 32 with value: 5.061694293348261.
# Best CV (LOYO) MAE: 5.061694293348261
# Best params: {'n_estimators': 389, 'max_depth': 2, 'learning_rate': 0.01009816635413452, 'subsample': 0.967374629033853, 'colsample_bytree': 0.9118118651665575}

# %% [markdown]
# ## 8. LOYO Error Breakdown by Season
# This cell evaluates the tuned model using LOYO validation
# and reports MAE separately for each held-out year.
#
# This helps diagnose season-specific performance degradation.

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import GroupKFold
from sklearn.metrics import mean_absolute_error
from xgboost import XGBRegressor

def eval_loyo_mae(X, y, groups, params):
    """
    LOYO evaluation: holds out one group (year) per fold.
    Returns dict: {year: MAE}
    """
    groups = pd.Series(groups).reset_index(drop=True)
    X = X.reset_index(drop=True)
    y = y.reset_index(drop=True)

    gkf = GroupKFold(n_splits=groups.nunique())
    fold_mae = {}

    for tr_idx, te_idx in gkf.split(X, y, groups):
        yr_vals = groups.iloc[te_idx].unique()
        if len(yr_vals) != 1:
            raise ValueError(f"Expected exactly one year in test fold, got: {yr_vals}")
        yr = int(yr_vals[0])

        model = XGBRegressor(**params, objective="reg:squarederror", random_state=42, n_jobs=-1)
        model.fit(X.iloc[tr_idx], y.iloc[tr_idx])
        pred = model.predict(X.iloc[te_idx])

        fold_mae[yr] = mean_absolute_error(y.iloc[te_idx], pred)

    return fold_mae

# ---- use the right variables for your 22-23 train split ----
best_params = study.best_params

groups_train = train_df["year"]          # 2022 & 2023 only
fold_mae = eval_loyo_mae(X_train, y_train, groups_train, best_params)

print("LOYO MAE by year (train only):")
for yr in sorted(fold_mae):
    print(yr, "->", fold_mae[yr])

print("Mean LOYO MAE:", float(np.mean(list(fold_mae.values()))))
# Out:
# LOYO MAE by year (train only):
# 2022 -> 5.03523608229377
# 2023 -> 5.0881525044027525
# Mean LOYO MAE: 5.061694293348261

# %% [markdown]
# ## 9. Final Model Training and 2024 Hold-Out Evaluation
# The best-performing model is retrained on all 2022–2023 data
# and evaluated once on the unseen 2024 season.
#
# This MAE represents the true out-of-sample performance.

# %%
best_model = XGBRegressor(**best_params, objective="reg:squarederror", random_state=42, n_jobs=-1)
best_model.fit(X_train, y_train)
pred_24 = best_model.predict(X_test)

print("Final 2024 MAE:", mean_absolute_error(y_test, pred_24))
# Out:
# Final 2024 MAE: 4.850488873762477
