# %%
What I have done in 04_qualifying
Target is qualifying Position
Features i used
best_lap_time, avg_lap_time, best_s1,best_s2,best_s3

What i should be doing here in 05_prequali_xgb_...
Target is still qualifying

FEatures is used should be FP1,FP2 and FP3, Historical races, team identity(teamate deltas), Practice weather
instead of using best_lap_time
i should use best_fp3_lap time (more indicative) best_fp_lap time , fp3 rank_best , fp rank percentile , best fp3 s1,s2,s3  , median fp laps, fp team ratios/deltas?, fp trackstatus (more-> fp  is unreliable , less -> fp is reliable)
